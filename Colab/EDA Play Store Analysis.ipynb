# %% [markdown]
# # Play Store Analysis — EDA

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ***[Google Play](https://play.google.com/)***, also known as the ***[Google Play Store](https://play.google.com/)*** or ***[Play Store](https://play.google.com/)*** and formerly Android Market, is a digital distribution service operated and developed by ***Google***. It serves as the official app store for certified devices running on the Android operating system and its derivatives, as well as ChromeOS, allowing users to browse and download applications developed with the Android software development kit (SDK) and published through Google. Google Play has also served as a digital media store, offering games, music, books, movies, and television programs. Content that has been purchased on Google Play Movies & TV and Google Play Books can be accessed on a web browser and through the Android and iOS apps.
#
# Applications are available through Google Play either for free or at a cost. They can be downloaded directly on an Android device through the proprietary Google Play Store mobile app or by deploying the application to a device from the Google Play website. Applications utilizing the hardware capabilities of a device can be targeted at users of devices with specific hardware components, such as a motion sensor (for motion-dependent games) or a front-facing camera (for online video calling). The Google Play Store had over 82 billion app downloads in 2016 and over 3.5 million apps published in 2017, while after a purge of apps, it is back to over 3 million. It has been the subject of multiple issues concerning security, in which malicious software has been approved and uploaded to the store and downloaded by users, with varying degrees of severity
#
#
# 1. **Vast App Library**:
# 	- Google Play Store boasts a massive collection of apps, ranging from productivity tools to games, entertainment, education, and more.
# 	- It offers apps developed by various companies and individuals, providing users with a wide range of choices for their needs.
#
# 2. **User Reviews and Ratings**:
# 	- Users can leave reviews and ratings for apps they've downloaded, helping others make informed decisions about whether to install them.
# 	- The review system often includes helpful feedback, troubleshooting tips, and insights into the app's performance, usability, and features.
#
# 3. **Personalized Recommendations**:
# 	- Google Play Store utilizes algorithms to offer personalized app recommendations based on users' past downloads, searches, and preferences.
# 	- This feature helps users discover new apps that align with their interests and needs, enhancing their overall experience.
#
# 4. **Regular Updates and Security**:
# 	- Apps on the Play Store are regularly updated by developers to fix bugs, introduce new features, and enhance performance.
# 	- Google employs various security measures, including Play Protect, to scan apps for malware and ensure they meet security standards before being made available for download.
#
# 5. **Multiple Payment Options**:
# 	- Users can purchase paid apps, games, and in-app content through various payment methods, including credit/debit cards, carrier billing, Google Play gift cards, and more.
# 	- This flexibility allows users to choose their preferred payment method for purchasing digital content.
#
# 6. **Beta Testing and Early Access**:
# 	- Developers can release beta versions of their apps through the Play Store, allowing users to test new features and provide feedback before the official release.
# 	- Early Access programs enable users to access and try out upcoming apps and games before they are widely available, offering developers valuable insights and users exclusive access.
#
# 7. **Family Sharing and Parental Controls**:
# 	- Google Play Store offers Family Library, allowing users to share purchased apps, games, movies, TV shows, and books with up to six family members.
# 	- Parents can set up parental controls to restrict access to certain types of content, prevent unauthorized purchases, and manage their children's app usage.
#
# 8. **Instant Apps**:
# 	- Instant Apps enable users to try out select apps without installing them on their devices, providing a streamlined experience for exploring new apps before committing to a download.
# 	- This feature allows users to access specific functionalities of an app directly from the Play Store, saving time and device storage.
#
# 9. **Localized Content**:
# 	- The Google Play Store offers localized content tailored to users' geographical locations and language preferences.
# 	- Users can discover apps, games, movies, and other content that are relevant to their region, culture, and language, enhancing their overall experience.
#
# 10. **Developer Tools and Resources**:
# 	- Google provides developers with a range of tools and resources to create, publish, and monetize their apps on the Play Store.
# 	- This includes the Android Developer Console, which offers insights into app performance, user engagement, and revenue metrics, helping developers optimize their offerings.

# %%
import IPython
IPython.display.Image(url="https://upload.wikimedia.org/wikipedia/commons/7/7a/Google_Play_2022_logo.svg")
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/7a/Google_Play_2022_logo.svg"/>

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# * [GitHub profile](https://www.github.com/FirmBase)
# * [GitHub project](https://github.com/FirmBase/EDA-Play-Store-Analysis.git)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# * Which applications earn most revenue in *Google Play*?
# * How is the compisition of paid and freeware applications.
# * Which applications are the most popular in platform?
# * Applications serving to different groups of age.
# * What and how many categories this digital market platform offers?
# * Most rated and reviwed applications by users.
# * How many people around the globe have downloaded and experienced that application?
# * Bandwidth and size of applications server has dealt.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# * The objective of my analysis is to provide insights about different applications and users.
# * Which category is giving most profit to developers.
# * Study the market growth and sentiments of people.
# * Analyze the behavior of the host, the pattern of change in preference of people in terms of different room types, unequal distribution of properties in each neighborhood group, etc.
# * Analyze diversity of applications, dominance, trends, genres, target users, etc.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.	Well-structured, formatted, and commented code is required.
# 2.	Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
# 	The additional credits will have advantages over other students during Star Student selection.
#
# 		[Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go without a single error logged.]
#
# 3.	Each and every logic should have proper comments.
# 4.	You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# Chart visualization code
# ```
#
#
# *	Why did you pick the specific chart?
# *	What is/are the insight(s) found from the chart?
# *	Will the gained insights help creating a positive business impact?
# 	Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5.	You have to create at least 20 logical & meaningful charts having important insights.
#
#
# 		[Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# 		U - Univariate Analysis,
#
# 		B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# 		M - Multivariate Analysis]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd						# Importing Pandas library
import numpy as np						# Importing Numpy library
import matplotlib.pyplot as plt			# Importing Matplot library
import seaborn as sns					# Importing Seaborn library
from datetime import datetime as dt		# Importing Datetime Module library
import missingno as msno				# Importing missingno library to visualize Nan Values

# %% [markdown]
# ### Dataset Loading

# %% [markdown]
# #### Loading dataset in **Google Colab**

# %%
# Load Dataset
# from google.colab import drive		# Mounting the google drive to the colab
# drive.mount('/content/drive')
# ps_app_file = "/content/drive/Dataset/Play Store Data.csv"
# ps_review_file = "/content/drive/Data/User Reviews.csv"

# %% [markdown]
# #### Loading dataset from **GitHub** respository

# %%
import requests
import io

def getFileFromURL(url):
	try:
		response = requests.get(url)
		if response.status_code == 200:
			file = pd.read_csv(io.StringIO(requests.get(url).content.decode('utf-8')))
			print(url, "loaded.")
			return file
		else:
			print("CSV fetching failed with response code:", response.status_code)
	except requests.exceptions.HTTPError as err:
		print("HTTP error:", err)
	except Exception as err:
		print("Error:", err)

ps_app_df, ps_review_df = getFileFromURL("https://raw.githubusercontent.com/FirmBase/EDA-Play-Store-Analysis/main/Dataset/Play%20Store%20Data.csv"), getFileFromURL("https://raw.githubusercontent.com/FirmBase/EDA-Play-Store-Analysis/main/Dataset/User%20Reviews.csv")
# Out:
# https://raw.githubusercontent.com/FirmBase/EDA-Play-Store-Analysis/main/Dataset/Play%20Store%20Data.csv loaded.
# https://raw.githubusercontent.com/FirmBase/EDA-Play-Store-Analysis/main/Dataset/User%20Reviews.csv loaded.

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ps_app_df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
# Dataset First Look
ps_review_df.head(3)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
ps_app_df.shape
# Out:
# (10841, 13)

# %%
# Dataset Rows & Columns count
ps_review_df.shape
# Out:
# (64295, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ps_app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Dataset Info
ps_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
ps_app_df[ps_app_df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
ps_review_df[ps_review_df.duplicated()]
# Out:
#                                App  \
# 7            10 Best Foods for You
# 15           10 Best Foods for You
# 78           10 Best Foods for You
# 79           10 Best Foods for You
# 100          10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 7                                                    NaN       NaN
# 15                                                   NaN       NaN
# 78                                                  Good  Positive
# 79                                                  Good  Positive
# 100    I like eat delicious food. That's I'm cooking ...  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
ps_app_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Missing Values/Null Values Count
ps_review_df.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
msno.matrix(ps_app_df)
# Out:
# <Axes: >

# %%
# Visualizing the missing values
msno.matrix(ps_review_df)
# Out:
# <Axes: >

# %% [markdown]
# * This graph gave us insights of missing values presence in entire dataset.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *	- Rows: 10841 and Columns: 13 of `Play Store Data`
# 	- Rows: 64295 and Columns: 5 of `Play Store Reviews`
# * Many duplicates present in both dataset with no *unique* values.
# * Missing values `NaN` is present uniformly on some rows.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
ps_app_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Columns
ps_review_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
ps_review_df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
# Dataset Describe
ps_app_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * ***App:*** Application name (this is not a 'package name' that is unique in entire store and android system).
# * ***Category:*** Categorical values describing application category like Art, Games, Social, Business, etc.
# * ***Rating:***	Numerical values given by contribution of users, rating ranges from 1.0 to 5.0.
# * ***Reviews:*** Number of reviews given by users on market platform.
# * ***Size:*** Size of application usually in 'M' for megabytes, 'K' for kilobytes and without any suffix represent 'B' bytes.
# * ***Installs:*** Number of users installed this particular application.
# * ***Type:*** Application labeled as 'Free' or 'Paid'.
# * ***Price:*** Cost of application if it's not free.
# * ***Content Rating:*** Rating given for audience on basis of age group.
# * ***Genres:*** Genre description of application like Art, Beauty, Books, Communication, etc.
# * ***Last Updated:*** Date of last update of application.
# * ***Current Ver:*** Version of application.
# * ***Android Ver:*** Target android version that application is compatible with.

# %% [markdown]
# * ***App:*** Application name (this is not a 'package name' that is unique in entire store and android system).
# * ***Translated_Review:*** Texts user wrote.
# * ***Sentiment:*** User sentiment positive, negative or neutral.
# * ***Sentiment_Polarity:*** Degree of sentiment of users ranging from -1.0 to 1.0.
# * ***Sentiment_Subjectivity:*** Degree to which a user has feelings, beliefs, or opinions ranging from 0.0 to 1.0.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
def countUniqueValues(df):
	dictionary_columns = {}
	for element in df.columns:
		dictionary_columns[element] = len(df[element].unique())
	return dictionary_columns

# %%
# Check Unique Values for each variable.
for key, value in countUniqueValues(ps_app_df).items():
	print(key, "—", value)
# Out:
# App — 9660
# Category — 34
# Rating — 41
# Reviews — 6002
# Size — 462
# Installs — 22
# Type — 4
# Price — 93
# Content Rating — 7
# Genres — 120
# Last Updated — 1378
# Current Ver — 2833
# Android Ver — 34

# %%
# Check Unique Values for each variable.
for key, value in countUniqueValues(ps_review_df).items():
	print(key, "—", value)
# Out:
# App — 1074
# Translated_Review — 27995
# Sentiment — 4
# Sentiment_Polarity — 5411
# Sentiment_Subjectivity — 4475

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Removing null rows
ps_app_df.dropna(inplace=True)

# Removing duplicate rows
ps_app_df.drop_duplicates(inplace=True)

ps_app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8886 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8886 non-null   object
#  1   Category        8886 non-null   object
#  2   Rating          8886 non-null   float64
#  3   Reviews         8886 non-null   object
#  4   Size            8886 non-null   object
#  5   Installs        8886 non-null   object
#  6   Type            8886 non-null   object
#  7   Price           8886 non-null   object
#  8   Content Rating  8886 non-null   object
#  9   Genres          8886 non-null   object
#  10  Last Updated    8886 non-null   object
#  11  Current Ver     8886 non-null   object
#  12  Android Ver     8886 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 971.9+ KB

# %%
# Write your code to make your dataset analysis ready.

# Removing null rows
ps_review_df.dropna(inplace=True)

# Removing duplicate rows
ps_review_df.drop_duplicates(inplace=True)

ps_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29692 entries, 0 to 64230
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     29692 non-null  object
#  1   Translated_Review       29692 non-null  object
#  2   Sentiment               29692 non-null  object
#  3   Sentiment_Polarity      29692 non-null  float64
#  4   Sentiment_Subjectivity  29692 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB

# %%
# Changing data type of 'Last Updated' column from string to datetime.
ps_app_df['Last Updated'] = pd.to_datetime(ps_app_df['Last Updated'])
ps_app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
# Removing other categorical values for Type, only 'Paid' and 'Free' is allowed
ps_app_df['Type'] = ps_app_df['Type'].apply(lambda type_: type_ if type_ == 'Paid' else 'Free')
ps_app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
# If any value in Rating column is above 5.0, it should be either be declare 'NaN' or 5.0 because 5 is the highest limit
ps_app_df['Rating'] = ps_app_df['Rating'].apply(lambda range: 5.0 if range > 5 else range)
ps_app_df.describe()
# Out:
#             Rating                   Last Updated
# count  8886.000000                           8886
# mean      4.187959  2017-11-22 00:29:00.445644800
# min       1.000000            2010-05-21 00:00:00
# 25%       4.000000            2017-09-21 00:00:00
# 50%       4.300000            2018-05-28 00:00:00
# 75%       4.500000            2018-07-23 00:00:00
# max       5.000000            2018-08-08 00:00:00
# std       0.522428                            NaN

# %%
# Remove dollar symbol from 'Price' column
ps_app_df['Price'] = ps_app_df['Price'].apply(lambda amount: float(amount[1:]) if '$' in str(amount) else float(amount))
ps_app_df[ps_app_df['Price'] != 0].head()
# Out:
#                                                App       Category  Rating  \
# 234  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 235                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 427                             Puffin Browser Pro  COMMUNICATION     4.0
# 476                      Moco+ - Chat, Meet People         DATING     4.2
# 477                                     Calculator         DATING     2.6
#
#     Reviews                Size  Installs  Type  Price Content Rating  \
# 234   11442                6.8M  100,000+  Paid   4.99       Everyone
# 235   10295                 39M  100,000+  Paid   4.99       Everyone
# 427   18247  Varies with device  100,000+  Paid   3.99       Everyone
# 476    1545  Varies with device   10,000+  Paid   3.99     Mature 17+
# 477      57                6.2M    1,000+  Paid   6.99       Everyone
#
#             Genres Last Updated  Current Ver Android Ver
# ...

# %%
# Converting string 'Installs' column to int datatype
ps_app_df['Installs'] = ps_app_df['Installs'].apply(lambda installs: int(str(installs)[:-1].replace('+', '').replace(',', '') if type(installs) is str else 0))
ps_app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159   19M     10000  Free    0.0       Everyone
# 1     967   14M    500000  Free    0.0       Everyone
# 2   87510  8.7M   5000000  Free    0.0       Everyone
# 3  215644   25M  50000000  Free    0.0           Teen
# 4     967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
# Converting values in 'Size' column to common unit i.e MB
def convertValuesToB(number):
	if type(number) is str:
		try:
			if 'M' in number or 'm' in number:
				return float(number[:-1]) * 1024 * 1024
			elif 'K' in number or 'k' in number:
				return float(number[:-1]) * 1024
			elif number == "Varies with device":
				return np.nan
				# return pd.NaT
			else:
				return float(number)
		except ValueError:
			return number
		except:
			return number

ps_app_df.loc[ps_app_df['App'] == "Life Made WI-Fi Touchscreen Photo Frame", 'Size'] = 1000/1000
ps_app_df['Size'] = ps_app_df['Size'].apply(convertValuesToB)
ps_app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size  Installs  Type  Price Content Rating  \
# 0     159  19922944.0     10000  Free    0.0       Everyone
# 1     967  14680064.0    500000  Free    0.0       Everyone
# 2   87510   9122611.2   5000000  Free    0.0       Everyone
# 3  215644  26214400.0  50000000  Free    0.0           Teen
# 4     967   2936012.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# ...

# %%
# Converting 'Reviews' column to int datatype from string.
ps_app_df['Reviews'] = ps_app_df['Reviews'].astype(int)
ps_app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size  Installs  Type  Price Content Rating  \
# 0      159  19922944.0     10000  Free    0.0       Everyone
# 1      967  14680064.0    500000  Free    0.0       Everyone
# 2    87510   9122611.2   5000000  Free    0.0       Everyone
# 3   215644  26214400.0  50000000  Free    0.0           Teen
# 4      967   2936012.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# ...

# %%
# Boxplot to get outliars

plt.figure(figsize=(16, 8))
plt.subplot(1, 4, 1)
ps_app_df[['Rating']].boxplot()
plt.xlabel('Range: 1.0 to 5.0')
plt.title('Box Plots for \'Rating\'')
plt.subplot(1, 4, 2)
ps_app_df[['Price']].boxplot()
plt.title('Box-Plot for \'Price\'')
plt.subplot(1, 4, 3)
ps_app_df[['Reviews']].boxplot()
plt.title('Box-Plot for \'Reviews\'')
plt.subplot(1, 4, 4)
ps_app_df[['Installs']].boxplot()
plt.title('Box-Plot for \'Installs\'')
plt.show()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * Dropped rows containing null values or `NaN`.
# * Dropped duplicated rows.
# * Changed `Last Updated` column values to DateTime datatype.
# * Rubbish values were present in `Type` while values can be **Paid** or **Free**. Filtered that out.
# * Values that were beyond the range of 'Rating' were filtered in `Rating`.
# * Removed '$' symbol from `Price`.
# * In `Installs`, symbols like '+' and '-' were present that been treated.
# * Size of the apps were in 'M' and 'K' format in `Size`. Changed it to complete numberic to represent size in 'B' (bytes).

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
sns.set_style("whitegrid")
ax = ps_app_df['Type'].value_counts().plot(kind='bar', color=['orange', 'steelblue'])
for p in ax.patches:
	ax.annotate(format(p.get_height(), '.1f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.title('Count of \'Free\' and \'Paid\' application')
plt.subplot(1, 2, 2)
plt.pie(ps_app_df['Type'].value_counts(), labels=ps_app_df['Type'].value_counts().index, autopct='%1.1f%%')
plt.title('Percentage of composition of \'Free\' and \'Paid\' application')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart gives visualize ranking between 'Free' and 'Paid' categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Freeware applications dominates market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Market seems to favour more free applications. Users may want to experience service first then pay for it.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
sns.set_style('whitegrid')
ax = sns.countplot(y='Content Rating', data=ps_app_df, palette=['green', 'orange', 'yellow', 'blue', 'red'])
for p in ax.patches:
	ax.annotate(format(p.get_width(), '.1f'), (p.get_width(), p.get_y() + p.get_height() / 2), ha='left', va='center', xytext=(5, 0), textcoords='offset points')
plt.xlabel('Count of application')
plt.title('Count of \'Content Rating\'')
plt.subplot(1, 2, 2)
pie_threshold = 100.0
pie_patches, pie_texts, pie_autotexts = plt.pie(ps_app_df['Content Rating'].value_counts(), labels=ps_app_df['Content Rating'].value_counts().index, autopct='%1.1f%%')
for i, (pie_size, pie_label) in enumerate(zip(ps_app_df['Content Rating'].value_counts(), ps_app_df['Content Rating'].value_counts().index)):
	if pie_size < pie_threshold:
		pie_texts[i].set_text('')
		pie_autotexts[i].set_text('')
plt.setp(plt.gca().get_xticklabels(), visible=False)
plt.title('Composition of \'Content Rating\'')
plt.show()
# Out:
# C:\Users\manut\AppData\Local\Temp\ipykernel_3152\104096564.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(y='Content Rating', data=ps_app_df, palette=['green', 'orange', 'yellow', 'blue', 'red'])
# C:\Users\manut\AppData\Local\Temp\ipykernel_3152\104096564.py:6: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.countplot(y='Content Rating', data=ps_app_df, palette=['green', 'orange', 'yellow', 'blue', 'red'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Good comparision for market sharing among content ratings where application fits.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Applications are pretty general that covers market. As it serves purpose for everyone.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Having rating for everyone does increase reach towards new users.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

plt.figure(figsize=(16, 8))
data_df = pd.merge(ps_app_df[['Price', 'Category']].groupby('Category').sum().reset_index(), ps_app_df['Category'].value_counts().reset_index(), on='Category', how='inner')
x_axis = np.arange(data_df.shape[0])
plt.bar(x_axis - 0.2, data_df['Price'], width=0.2, label='Price')
plt.bar(x_axis + 0.2, data_df['count'], width=0.2, label='Application count')
for i, v in enumerate(data_df['Price']):
	plt.text(x_axis[i] - 0.2, v + 0.5, str(round(v, 1)), fontsize=8, ha='center')
for i, v in enumerate(data_df['count']):
	plt.text(x_axis[i] + 0.2, v + 0.5, str(round(v, 2)), ha='center')
plt.xticks(x_axis, data_df['Category'], rotation=90)
plt.title('Number of applications per category', size=20)
plt.ylabel('Number of apps')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Bar chart will represent clear number of application with categories along with prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **FAMILY** has the highest number of application then follows **GAME**.
# * All the other categories are low and same around.
# * While **FINANCE**, **FAMILY** and **LIFESTYLE** seems to earn large revenue on their category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * All those application that belongs to the categories that have less number seems to gain less money.
# * Only **TOOLS** category has less number of application that still earns more revenue.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

plt.figure(figsize=(16, 6))
sns.set_style('whitegrid')
sns.lineplot(x='Last Updated', y='count', data=ps_app_df['Last Updated'].value_counts().reset_index(), color='blue', linewidth=1)
# plt.xlabel('Time')
plt.ylabel('Application counts')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Line plot is used to display variation with respect to time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Application are getting most updates with time.
# * It can be speculated that more users must be joining smartphone ecosystem, as smartphone sales were booming at that time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * At this time, market will continoue to grow.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

column_numbers = 10

plt.figure(figsize=(8, 4))
sns.set_style('whitegrid')
ax = sns.barplot(x='App', y='Reviews', data=ps_app_df.drop_duplicates(subset='App', inplace=False).sort_values(by='Reviews', ascending=False, na_position='last', axis='index').head(column_numbers), palette='viridis')
# Annotate each bar with its value
for p in ax.patches:
	formatted_value = None
	if p.get_height() > 1000000:
		formatted_value = format(p.get_height() / 10000000, '.1f') + 'M'
	elif p.get_height() > 1000:
		formatted_value = format(p.get_height() / 1000, '.1f') + 'K'
	else:
		formatted_value = format(p.get_height(), '.1f')
	ax.annotate(formatted_value, (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.xlabel('Application')
plt.xticks(rotation=90)
plt.title(f'Top {column_numbers} most reviewed application')
plt.show()
# Out:
# C:\Users\manut\AppData\Local\Temp\ipykernel_3152\2146036878.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='App', y='Reviews', data=ps_app_df.drop_duplicates(subset='App', inplace=False).sort_values(by='Reviews', ascending=False, na_position='last', axis='index').head(column_numbers), palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Depiction of top most reviews application.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Top 4 applications are socail media and messanger application. This represents their reach.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Social media is more popular than entertainment and games.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

plt.figure(figsize=(8, 8))
plt.pie(ps_app_df[ps_app_df['Type'] == 'Paid'][['Content Rating', 'Price']].groupby('Content Rating')['Price'].sum(), labels=ps_app_df[ps_app_df['Type'] == 'Paid'][['Content Rating', 'Price']].groupby('Content Rating').sum().index, autopct=lambda x: '{:.4f}% — {:.0f}$'.format(x, sum(ps_app_df[ps_app_df['Type'] == 'Paid'][['Content Rating', 'Price']].groupby('Content Rating')['Price'].sum())*x/100), shadow=True)
plt.title('Composition of \'Price\' based on \'Content Rating\'')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart gives good composition of `Content Rating` with `Price` distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Application content rated for **Everyone** is earns most revenue. Then, for **Teen**. Other than that are all miniscule.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Application if resides in mature content, will miss most of the users. And thus, it will effect on revenue.
# * Although **Teen** content has significant revenue. But content for **Everyone** has occupied 12 times more share than **Teen**.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

plt.figure(figsize=(16, 8))
sns.set_style('whitegrid')
ax = sns.barplot(x='Category', y='Installs', data=ps_app_df.groupby('Category')['Installs'].mean().reset_index().sort_values(by='Installs', ascending=False, na_position='last', axis='index').head(column_numbers), palette='viridis')
# Annotate each bar with its value
for p in ax.patches:
	ax.annotate(format(p.get_height() / 10000000, '.1f') + 'M', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.xlabel('Application categories')
plt.xticks(rotation=90)
plt.title(f'Top most downloaded application categories')
plt.show()
# Out:
# C:\Users\manut\AppData\Local\Temp\ipykernel_3152\2585574118.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Category', y='Installs', data=ps_app_df.groupby('Category')['Installs'].mean().reset_index().sort_values(by='Installs', ascending=False, na_position='last', axis='index').head(column_numbers), palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Column bar chart can compare all categories with very low values. Thus this graph fits best for this data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Communication** category has the highest downloads, almost 25% more than other categories. It is understandle that **communication** based applications are like Messanger or Social media platform. Thus, motivating their peers to download same application.
# * Following there are **Social**, **Photography**, **Travels**, **News**, **Shopping**, **Games**, etc. which are most downloaded.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Social**, **Photography**, **Travels**, **News**, **Shopping**, **Games**, etc. These categorical applications are regularly used. Other categorical applications might used occasionally. And users who download are less too.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
pie_threshold = 100.0
# This line of code below were for showing table which were not visible in Pie Chart
# pie_table = []
pie_patches, pie_texts, pie_autotexts = plt.pie(ps_app_df['Android Ver'].value_counts(), labels=ps_app_df['Android Ver'].value_counts().index, labeldistance=1.05, autopct='%1.1f%%')
for i, (pie_size, pie_label) in enumerate(zip(ps_app_df['Android Ver'].value_counts(), ps_app_df['Android Ver'].value_counts().index)):
	if pie_size < pie_threshold:
		# This line of code below were for showing table which were not visible in Pie Chart
		# pie_table.append([pie_texts[i].get_text(), pie_autotexts[i].get_text()])
		pie_texts[i].set_text('')
		pie_autotexts[i].set_text('')
plt.setp(plt.gca().get_xticklabels(), visible=False)
plt.title('Android OS version composition')
plt.subplot(1, 2, 2)
# These two lines of code below were for showing table which were not visible in Pie Chart
# plt.table(cellText=pie_table, cellLoc='center', colLabels=['Android Ver', 'Composition percentage'])
# plt.axis('off')
sns.barplot(x='Android Ver', y='count', data=ps_app_df['Android Ver'].value_counts().reset_index(), palette='deep')
plt.xlabel('Android OS versions')
plt.ylabel('Number of application')
plt.xticks(rotation=90)
plt.suptitle('Android OS minimum version requirements')
plt.show()
# Out:
# C:\Users\manut\AppData\Local\Temp\ipykernel_3152\3886581960.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Android Ver', y='count', data=ps_app_df['Android Ver'].value_counts().reset_index(), palette='deep')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Pie chart is best to give composition or distribution of values in variables but since pie chart is unable to provide those values which are very low hence bar chart has been used along with it.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most application seems to require Android OS version `4.1 and up`. But at almost same number `4.3.0 and up`, `4.0 and up` and `4.4 and up` are required too.
# * From down least Android OS version that makes minority of applications are below `2.3 and up`.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Developers should try to make minimum requirment of Android OS version to **Gingerbread** i.e. `2.3 and up` if possible.
# * Android OS version `2.3 and up` is very outdated. Thus it will nearly make impossible to develop certain applications. So, better developers develop application that requires Android OS **Ice Cream Sandwich** i.e. `4.0 and up`. That will still cover majority of users.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

plt.figure(figsize=(16, 4))
ax = sns.barplot(x='Installs', y='Type', data=ps_app_df.groupby('Type')['Installs'].mean().reset_index(), palette=['orange', 'steelblue'])
for p in ax.patches:
	ax.annotate(format(p.get_width() / 1000000, '.1f') + 'M', (p.get_width(), p.get_y() + p.get_height() / 2), ha='left', va='center', xytext=(5, 0), textcoords='offset points')
plt.title('Average downloads of application \'Free\' versus \'Paid\'')
plt.show()
# Out:
# C:\Users\manut\AppData\Local\Temp\ipykernel_3152\226475661.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Installs', y='Type', data=ps_app_df.groupby('Type')['Installs'].mean().reset_index(), palette=['orange', 'steelblue'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Bar chart can provide significant comparision to those variables who has very high value and at the same time other variable has very low value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most users have downloaded **free** application from store that it dominates **paid** application with almost 177 times.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Clearly, **free** applications are most downloaded. So, a different strategy can be opted to monetize application. Like limiting features in application and motivating user to do **In-App** purchases or application can also be monetized by advertisements. Google's advertisement is pretty straight forward to implement.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

plt.figure(figsize=(16, 4))
sns.set_style('whitegrid')
sns.lineplot(x='Installs', y='Reviews', data=ps_app_df.groupby('App')[['Installs', 'Reviews']].mean().reset_index().sort_values(by='Installs', ascending=True, na_position='last', axis='index'), marker='o', linestyle='-', color='blue', linewidth=1)
plt.xlabel('Installs')
plt.ylabel('Reviews')
plt.title('\'Install\' and \'Reviews\' trend')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Line graph gives clear relation between variable with large group of data and most important the **trajectory**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Clearly, **linear** relation can be observed. `Installs` and `Reviews` are directly proportional.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * It is quite obvious that more downloads will bring more users, thus their reviews too.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

plt.figure(figsize=(8, 4))
ax = sns.barplot(data=ps_review_df[['App', 'Sentiment']].groupby('Sentiment').value_counts().reset_index(), x='Sentiment', y='count', palette=['red', 'steelblue', 'green'])
for p in ax.patches:
	ax.annotate(format(p.get_height(), '.1f'), (p.get_x() + p.get_width() / 2., p.get_height() + 1), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.xlabel('Sentiment')
plt.ylabel('Sentiment counts')
plt.title('Sentiments')
plt.show()
# Out:
# C:\Users\manut\AppData\Local\Temp\ipykernel_3152\2046685423.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=ps_review_df[['App', 'Sentiment']].groupby('Sentiment').value_counts().reset_index(), x='Sentiment', y='count', palette=['red', 'steelblue', 'green'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This graph gives comparision of number of users that gave their reviews. There sentiment can be compare with this graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Reviews of **Positive** experience recorded is higher than other. It can be interpret as people with nice experience gives most reviews and least are given by those users who had no good nor bad, which is quite understandable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Although **Negative** experience reviews are not high that does not mean a person with horrible experience would not give bad review, as clear from graph it is second highest reviewed and thus that user must have given low rating.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

plt.figure(figsize=(8, 8))
sns.scatterplot(x='Sentiment_Subjectivity', y='Sentiment_Polarity', data=ps_review_df, hue='Sentiment')
plt.title('Sentiment Polarity versus Sentiment Subjectivity')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This scatter plots is helpful to observe and show relationships between two `Sentiment_Polarity` and `Sentiment_Subjectivity` with public `Sentiment`. The dots in a scatter plot not only report the values of individual data points, but also patterns when the data are taken as a whole. Identification of correlational relationships are common with scatter plots.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The polarity score ranges from -1 to 1. A score of -1 means the words are super negative, like “disgusting” or “awful.” A score of 1 means the words are super positive, like “excellent” or “best.” Subjectivity score, on the other hand, goes from 0 to 1. If it’s close to 1, it means the sentence has a lot of personal opinion instead of just facts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Low polarity score below zero is problem, as user experience was bad.

# %% [markdown]
# #### Chart - 13 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(10, 8))
sns.heatmap(ps_app_df[['Rating', 'Reviews', 'Size', 'Installs', 'Price']].corr(), annot=True, vmin=-1, vmax=1, linecolor='black', linewidths=0.5)
plt.show()

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(5, 4))
sns.heatmap(ps_review_df[['Sentiment_Polarity', 'Sentiment_Subjectivity']].corr(), annot=True, vmin=-1, vmax=1, linecolor='black', linewidths=0.5)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A correlation heatmap is a graphical representation of a correlation matrix representing the correlation between different variables.
#
# * The color of each cell visualize the strength and direction of the correlation.
# 	* Darker colors indicate stronger correlations, while lighter colors indicate weaker correlations.
# 	* Positive correlations (when one variable increases, the other variable tends to increase) are usually represented by warm colors, such as red or orange.
# 	* Negative correlations (when one variable increases, the other variable tends to decrease) are usually represented by cool colors, such as blue or green.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Correlation coefficient can range from -1.0 to +1.0.
# 	* If the value is 1, it is said to be a positive correlation between two variables. This means that when one variable increases, the other variable also increases.
# 	* If the value is -1, it is said to be a negative correlation between the two variables. This means that when one variable increases, the other variable decreases.
# 	* If the value is 0, there is no correlation between the two variables. This means that the variables changes in a random manner with respect to each other.
#
# *	* `Reviews` and `Rating` has less than moderate positive correlation.
# 	* `Installs` and `Reviews` has moderate positive correlation.
# 	* `Installs` and `Rating` has moderate positive correlation.
# 	* Rest all has weak correlation.
#
# * Correlation between `Sentiment_Polarity` and `Sentiment_Subjectivity` is very weak.

# %% [markdown]
# #### Chart - 14 - Pair Plot

# %%
# Pair Plot visualization code

plt.figure(figsize=(32, 32))
sns.set_palette('coolwarm')
sns.pairplot(ps_app_df[['Rating', 'Reviews', 'Size', 'Installs', 'Price']], kind='reg')
plt.show()

# %%
# Pair Plot visualization code

plt.figure(figsize=(8, 8))
sns.set_palette('coolwarm')
sns.pairplot(ps_review_df[['Sentiment_Polarity', 'Sentiment_Subjectivity']], kind='reg')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Pairplot visualizes given data to find the relationship between them where the variables can be continuous or categorical.
# Pair Plot provides pairwise relationships in a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *	* `Installs` and `Reviews` seems to have moderate positive dependency i.e. directly proportional, as it was obvious they will have linear relation.
# 	* `Reviews` and `Size` seems to show little bit high positive dependency.
# 	* `Size` and `Installs` seems to show positive dependency
#
# * `Sentiment_Polarity` and `Sentiment_Subjectivity` has almost no dependency.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * Applications should be free first so users can have first hand experience, this usually makes to target larger audience. A trail or limited functionality would be better.
# * Developers should make applications that has reach of all ages.
# * Social media platform are way more popular, thus they have large influence.
# * Android `4.1 and up` required by most of the applications, an application should be atleast compatible with Android OS **Ice Cream Sandwitch** i.e. Android `4.0 and up`.
# * **Communication** based application has most downloads then follows **Social**, **Productivity**, **Photography**, **Travelling**, **Games**, **Shopping** and **Entertainment**.
# * **FINANCE**, **FAMILY** and **LIFESTYLE** earns most revenue.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Throughout our analysis, we have gained a deeper understanding of various aspects of widely used application store, [Google Play](https://play.google.com/), including pricing dynamics of applications, content distribution, types, generes and number of reviews. One of the key takeaways from our analysis is the importance of popularity in determining revenue.
#
# * There is no doubt that this store is dominated by **free** applications or they generate revenue from **In-App** advertisement.
# * We found that certain age groups are most beneficial of these application services, targeting these users has higher chances of monetizing application.
# * Social media applications reflects the influence of demand in most users as they bring their social circles with them.
# * Generally those users who rate and contribute reviews had positive experience.
# * Most downloaded application has most user's reviews.
#
# In conclusion, our EDA project has illuminated the complex landscape of dynamic digital services, providing valuable insights for both users and developers. By harnessing the power of python and data analysis, we have the potential to make more informed decisions, ultimately enhancing the understanding of digital market and experience for all new developers. This project serves as a testament to the importance of data-driven decision-making in new ideas that will make more convenience to users and business opportunities.
